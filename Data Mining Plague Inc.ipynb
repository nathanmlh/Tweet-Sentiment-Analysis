# %%
import json
import time
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
from collections import defaultdict
import operator

# %%
acessToken = 'XXXXX'
secretAccessToken = 'XXXXXX'
costumerKey = 'XXXXX'
SecretCostumerKey = 'XXXXX'

# %%
# Create a StreamListener class 
class MyListener(StreamListener):

    def __init__(self, time_limit=300):
        self.start_time = time.time()
        self.limit = time_limit
        self.outFile = open('output.json', 'a')
        super(MyListener, self).__init__()
    
    def on_data(self, data):
        if (time.time() - self.start_time) < self.limit:
            self.outFile.write(data)
            self.outFile.write('\n')
            time.sleep(3)
            return True
        else:
            self.outFile.close()
            return False

    def on_error(self, status):
        print(status)
        if status_code == 420:
            sleep(10)
            #returning False in on_error disconnects the stream
            return False

# %%
auth = OAuthHandler(costumerKey, SecretCostumerKey)
auth.set_access_token(acessToken, secretAccessToken)
myStream = Stream(auth, MyListener(time_limit=28800))

# %%
myStream.filter(track=[' COVID-19 OR coronavirus OR quarantine OR covid ', 'lang:en', 'until:2020-11-10', 'since:2020-09-15', '-filter:retweets'], 
                locations=[-171.791110603, 18.91619, -66.96466, 71.3577635769])
# Out:
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# /usr/lib/python3.6/http/client.py in _readinto_chunked(self, b)
#     596                 if len(mvb) <= chunk_left:
# --> 597                     n = self._safe_readinto(mvb)
#     598                     self.chunk_left = chunk_left - n
#
# /usr/lib/python3.6/http/client.py in _safe_readinto(self, b)
#     643             if not n:
# --> 644                 raise IncompleteRead(bytes(mvb[0:total_bytes]), len(b))
#     645             mvb = mvb[n:]
#
# IncompleteRead: IncompleteRead(0 bytes read, 512 more expected)
#
# During handling of the above exception, another exception occurred:
#
# IncompleteRead                            Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/urllib3/response.py in _error_catcher(self)
#     361             try:
# --> 362                 yield
#     363
#
# ...
